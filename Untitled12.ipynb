# %% [markdown]
# <a href="https://colab.research.google.com/github/Preetikumari1215/Design_and_Development_of_Sanskrit_Language_Translator_and-Analysis_Tool_using_NLP_Techniques/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("acomquest/Saamayik")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/5.80M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/328k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/331k [00:00<?, ?B/s]
# data/test_ood-00000-of-00001.parquet:   0%|          | 0.00/714k [00:00<?, ?B/s]
# ...
# Generating test_ood split:   0%|          | 0/4047 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation', 'source'],
#         num_rows: 43493
#     })
#     validation: Dataset({
#         features: ['translation', 'source'],
#         num_rows: 2416
#     })
#     test: Dataset({
#         features: ['translation', 'source'],
#         num_rows: 2417
#     })
#     test_ood: Dataset({
#         features: ['translation', 'source'],
#         num_rows: 4047
#     })
# })

# %%
ds["train"][:5]['translation']
# Out:
# [{'en': '"Save it with Ctrl, S."', 'sa': '"Ctrl, S नुत्वा रक्षन्तु।"'},
#  {'en': 'Teacher will teach the students only once.',
#   'sa': 'गुरुः छात्रान् एकवारं पाठयति ।'},
#  {'en': '"To recreate this animation, I have to take two images out of this stack which is very easy."',
#   'sa': 'चित्रचालनमिदं पुनः कर्तुं मया अस्याः राशेः चित्रद्वयं स्वीकरणीयमस्ति । इदमतीव सुलभमस्ति ।'},
#  {'en': 'I will choose Colors options by clicking on it.',
#   'sa': 'वयं  Colors विकल्पं तस्योपरि नोदनेन चिनुमः ।'},
#  {'en': '"""See the example here - one mountain, four villages, four paths leading to one goal towards flag."""',
#   'sa': '"""अत्र कानिचन उदाहरणानि पश्याम:- एक: पर्वत:, चत्वारो ग्रामा:, चत्वारो मार्गा: ये लक्ष्यं (पताकां) प्रति गच्छन्ति।"""'}]

# %%
ds["validation"][:5]['translation']
# Out:
# [{'en': 'Those are brave men.', 'sa': 'ते वीराः ।'},
#  {'en': 'Infinite loop  can cause the system to become unresponsive.',
#   'sa': "'इन्फ़ैनेट् लूप्' इतीदं व्यवस्थां निरुत्तरां कारयति ।"},
#  {'en': '"""And they spit upon him, and took the reed, and smote him on the head."""',
#   'sa': 'ततस्तस्य गात्रे निष्ठीवं दत्वा तेन वेत्रेण शिर आजघ्नुः।'},
#  {'en': 'These two are dates.', 'sa': 'एते तिथी ।'},
#  {'en': '"""And when there had been much disputing, Peter rose up, and said unto them, Men and brethren, ye know how that a good while ago God made choice among us, that the Gentiles by my mouth should hear the word of the gospel, and believe."""',
#   'sa': '"""बहुविचारेषु जातषु पितर उत्थाय कथितवान्, हे भ्रातरो यथा भिन्नदेशीयलोका मम मुखात् सुसंवादं श्रुत्वा विश्वसन्ति तदर्थं बहुदिनात् पूर्व्वम् ईश्वरोस्माकं मध्ये मां वृत्वा नियुक्तवान्।"""'}]

# %%
ds["test"][:5]['translation']
# Out:
# [{'en': 'Eclipse also helps the programmer to find out errors.',
#   'sa': 'एक्लिप्स् इति प्रोग्रामर् कृते दोषान्वेषणे अपि साहाय्यं करोति।'},
#  {'en': '"""We having the same spirit of faith, according as it is written, I believed, and therefore have I spoken; we also believe, and therefore speak;"""',
#   'sa': 'विश्वासकारणादेव समभाषि मया वचः। इति यथा शास्त्रे लिखितं तथैवास्माभिरपि विश्वासजनकम् आत्मानं प्राप्य विश्वासः क्रियते तस्माच्च वचांसि भाष्यन्ते।'},
#  {'en': 'Then it will automatically begin searching for drivers. I will click on Cancel.',
#   'sa': '"तदा, तत्स्वयं ड्रैवर निमित्तम् अन्वेष्यति। अहं \'Cancel\' इत्यस्योपरि नुदामि।"'},
#  {'en': '"The iterator will be set to each of the indices values for each iteration- say, 1 comma 1, then 1 comma 2 and so on."',
#   'sa': '"सर्वेभ्यः इटरेशन्-अर्थम्, iterator इतीदं प्रत्येकस्मै इण्डेक्स्-वेल्यू-इत्यस्मै सेट् क्रियते । 1,1 पश्चात् 1,2  एवम्…"'},
# ...

# %%
# !pip install transformers

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("translation", model="tencent/Hunyuan-MT-7B")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-0004-of-0004.safetensors:   0%|          | 0.00/75.5M [00:00<?, ?B/s]
# model-0001-of-0004.safetensors:   0%|          | 0.00/5.27G [00:00<?, ?B/s]
# model-0002-of-0004.safetensors:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# model-0003-of-0004.safetensors:   0%|          | 0.00/5.36G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/892 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.4M [00:00<?, ?B/s]
# Device set to use cuda:0
# ...
